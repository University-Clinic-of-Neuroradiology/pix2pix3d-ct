# %%
import os
import pydicom

# %%
path = '/mnt/d/pix2pix3d-ct/pat/real/164983005-11/sub/0001.dcm'
ds = pydicom.dcmread(path)

# %%
print(ds)
# print all tags (also hidden tags)
for elem in ds.iterall():
    # save in txt file
    print(elem)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 186
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.4.7.12002.30000017022710102189700010030
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.410.200010.99.3.5
# (0002, 0013) Implementation Version Name         SH: 'INF_4.5'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 6'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'AXIAL', '3DANGIO', 'SUB']
# (0008, 0012) Instance Creation Date              DA: '20170304'
# (0008, 0013) Instance Creation Time              TM: '143431.690000'
# ...
